# %%
# %pip install funpymodeling
# %pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
from google.colab import files
files.upload()

# %%
df=pd.read_excel("microretailer_mit_lift_lab.xlsx")
df.head(10)

# %%
df_2= ['_updated_by','232_type_of_store','99_does_the_micro_retailer_exhibits_products_outside_','102_does_the_micro_retailer_sells_fresh_products_','184_store_devices','5_change_store_space_last_year','6_change_employees_average_salary_last_year','18_sales_records','145_number_direct_competitors','186_internet_connection', '49_inventory_records','210_sales_channels','189_payment_methods','214_customer_relationship_tools','193_sales_planning_tools','60_services','69_why_not_services','158_charact_organize_products_on_shelves','161_actions_stockouts','234_willingness_participate_workshop']
df2= df[df_2]
df2.head(10)

# %%
total_nulos=df2.isnull().sum()
total_nulos
# Out:
# _updated_by                                                0
# 232_type_of_store                                          0
# 99_does_the_micro_retailer_exhibits_products_outside_      0
# 102_does_the_micro_retailer_sells_fresh_products_          0
# 184_store_devices                                          2
# 5_change_store_space_last_year                            72
# 6_change_employees_average_salary_last_year               86
# 18_sales_records                                          61
# 145_number_direct_competitors                             68
# 186_internet_connection                                   63
# 49_inventory_records                                      61
# 210_sales_channels                                        89
# 189_payment_methods                                       64
# 214_customer_relationship_tools                           76
# 193_sales_planning_tools                                  89
# 60_services                                               94
# 69_why_not_services                                      130
# 158_charact_organize_products_on_shelves                  79
# 161_actions_stockouts                                     79
# 234_willingness_participate_workshop                      73
# dtype: int64

# %%
df_retail=df2.fillna('Unknown')

# %%
total_nulos=df_retail.isnull().sum().sum()
total_nulos
# Out:
# 0

# %%
df_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   _updated_by                                            171 non-null    object
#  1   232_type_of_store                                      171 non-null    object
#  2   99_does_the_micro_retailer_exhibits_products_outside_  171 non-null    object
#  3   102_does_the_micro_retailer_sells_fresh_products_      171 non-null    object
#  4   184_store_devices                                      171 non-null    object
#  5   5_change_store_space_last_year                         171 non-null    object
#  6   6_change_employees_average_salary_last_year            171 non-null    object
#  7   18_sales_records                                       171 non-null    object
#  8   145_number_direct_competitors                          171 non-null    object
#  9   186_internet_connection                                171 non-null    object
#  10  49_inventory_records                                   171 non-null    object
#  11  210_sales_channels                                     171 non-null    object
#  12  189_payment_methods                                    171 non-null    object
#  13  214_customer_relationship_tools                        171 non-null    object
#  14  193_sales_planning_tools                               171 non-null    object
#  15  60_services                                            171 non-null    object
#  16  69_why_not_services                                    171 non-null    object
#  17  158_charact_organize_products_on_shelves               171 non-null    object
#  18  161_actions_stockouts                                  171 non-null    object
#  19  234_willingness_participate_workshop                   171 non-null    object
# dtypes: object(20)
# memory usage: 26.8+ KB

# %%
tabla1 = df_retail['5_change_store_space_last_year'].value_counts()
# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
tabla1.plot(kind='bar', rot=45, color='red')
plt.xlabel('Cambios en el Espacio de la Tienda en el Último Año')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Cambios en el Espacio de la Tienda en el Último Año')
plt.show()

# %%
tabla2= freq_tbl(df_retail['232_type_of_store'])
#Realizamos grafico de área pero solo filtramos los que tengan una frecuencia mayor a 1
filtro2= tabla2[tabla2['frequency']>1]
Filtro2_index= filtro2.set_index('232_type_of_store')

ax=Filtro2_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
plt.show()

# %%
tabla3 = df_retail['186_internet_connection'].value_counts(normalize=True) * 100
plt.figure(figsize=(8, 8))
plt.pie(tabla3, labels=tabla3.index, autopct='%1.1f%%', startangle=140, colors=['red', 'green', 'blue'])
plt.title('Porcentaje de Conexión a Internet')
plt.show()

# %%
tabla4 = df_retail['102_does_the_micro_retailer_sells_fresh_products_'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(tabla4, labels=tabla4.index, autopct='%1.1f%%', startangle=140)
plt.title('Porcentaje de Venta de Productos Frescos en Micro Minoristas')
plt.show()

# %%
frecuencias_productos = df_retail['184_store_devices'].value_counts()
tabla5 = frecuencias_productos.head(5)
plt.figure(figsize=(10, 6))
plt.bar(tabla5.index, tabla5.values, color='blue')
plt.xlabel('Dispositivos')
plt.ylabel('Frecuencia')
plt.title('Los 5 dispositivos más utilizados')
plt.xticks(rotation=45)
plt.show()

# %%
tabla6=freq_tbl(df_retail['_updated_by'])
tabla6
Filtro1= tabla6.set_index('_updated_by')
top_20_categories = Filtro1.head(15)
top_20_categories['frequency'].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Gráfico de las personas con mayores actualizaciones')
plt.show()

# %%
total_registros = len(df_retail)
tabla7 = (df_retail['6_change_employees_average_salary_last_year'].value_counts() / total_registros) * 100
tabla7= tabla7.sort_index()
plt.figure(figsize=(10, 6))
plt.plot(tabla7.index, tabla7.values, marker='o', linestyle='-', color='b')
plt.xlabel('Cambios en el Salario Promedio de Empleados el Último Año')
plt.ylabel('Porcentaje (%)')
plt.title('Porcentaje de Cambios en el Salario Promedio de Empleados el Último Año')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
tabla8 = df_retail['18_sales_records'].value_counts()
plt.figure(figsize=(10, 6))
tabla8.plot(kind='bar', rot=90, color='red')
plt.xlabel(' Ventas')
plt.ylabel('Frecuencia')
plt.title('Los registros de ventas se realizan en:')
plt.show()

# %%
tabla9 = df_retail['145_number_direct_competitors'].value_counts()
plt.figure(figsize=(10, 6))
tabla9.plot(kind='bar', rot=0, color='brown')
plt.xlabel('Número de Competidores Directos')
plt.ylabel('Frecuencia')
plt.title('Frecuencia del Número de Competidores Directos')
plt.show()

# %%
tabla10 = df_retail['99_does_the_micro_retailer_exhibits_products_outside_'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(tabla10.index, tabla10.values)
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('Los micro minoristas ,¿Exhiben productos afuera?')
plt.show()

# %%
tabla11 = df_retail['49_inventory_records'].value_counts()
plt.figure(figsize=(10, 6))
tabla11.plot(kind='bar', rot=45, color='pink')
plt.xlabel('Registros de Inventario')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Registros de Inventario')
plt.show()

# %%
frecuencias = df_retail['210_sales_channels'].value_counts()
porcentajes = (frecuencias / len(df_retail)) * 100
tabla_frecuencia = pd.DataFrame({'Frecuencia': frecuencias, 'Porcentaje (%)': porcentajes})
tabla12 = tabla_frecuencia.sort_values(by='Frecuencia', ascending=False)
tabla12.style.format({'Porcentaje (%)': '{:.2f}%'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_99a1a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99a1a_level0_col0" class="col_heading level0 col0" >Frecuencia</th>
#       <th id="T_99a1a_level0_col1" class="col_heading level0 col1" >Porcentaje (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >210_sales_channels</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99a1a_level0_row0" class="row_heading level0 row0" >Unknown</th>
#       <td id="T_99a1a_row0_col0" class="data row0 col0" >89</td>
#       <td id="T_99a1a_row0_col1" class="data row0 col1" >52.05%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row1" class="row_heading level0 row1" >Redes sociales (e.g. Facebook, Instagram)</th>
#       <td id="T_99a1a_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_99a1a_row1_col1" class="data row1 col1" >6.43%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row2" class="row_heading level0 row2" >WhatsApp</th>
#       <td id="T_99a1a_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_99a1a_row2_col1" class="data row2 col1" >5.85%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row3" class="row_heading level0 row3" >Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_99a1a_row3_col1" class="data row3 col1" >5.26%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row4" class="row_heading level0 row4" >Llamada a Teléfono fijo</th>
#       <td id="T_99a1a_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_99a1a_row4_col1" class="data row4 col1" >3.51%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row5" class="row_heading level0 row5" >Llamada a Teléfono celular,WhatsApp</th>
#       <td id="T_99a1a_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_99a1a_row5_col1" class="data row5 col1" >3.51%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row6" class="row_heading level0 row6" >Llamada a Teléfono celular</th>
#       <td id="T_99a1a_row6_col0" class="data row6 col0" >5</td>
#       <td id="T_99a1a_row6_col1" class="data row6 col1" >2.92%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row7" class="row_heading level0 row7" >Llamada a Teléfono celular,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row7_col0" class="data row7 col0" >5</td>
#       <td id="T_99a1a_row7_col1" class="data row7 col1" >2.92%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row8" class="row_heading level0 row8" >Ninguno</th>
#       <td id="T_99a1a_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_99a1a_row8_col1" class="data row8 col1" >1.75%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row9" class="row_heading level0 row9" >Página web propia</th>
#       <td id="T_99a1a_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_99a1a_row9_col1" class="data row9 col1" >1.75%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row10" class="row_heading level0 row10" >Llamada a Teléfono celular,Llamada a Teléfono fijo,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_99a1a_row10_col1" class="data row10 col1" >1.75%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row11" class="row_heading level0 row11" >Llamada a Teléfono celular,Llamada a Teléfono fijo,WhatsApp</th>
#       <td id="T_99a1a_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_99a1a_row11_col1" class="data row11 col1" >1.17%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row12" class="row_heading level0 row12" >Aplicación móvil (e.g. Rappi, Uber Eats)</th>
#       <td id="T_99a1a_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_99a1a_row12_col1" class="data row12 col1" >1.17%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row13" class="row_heading level0 row13" >conocidos paquetes cerrados</th>
#       <td id="T_99a1a_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_99a1a_row13_col1" class="data row13 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row14" class="row_heading level0 row14" >Físico </th>
#       <td id="T_99a1a_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_99a1a_row14_col1" class="data row14 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row15" class="row_heading level0 row15" >Aplicación móvil (e.g. Rappi, Uber Eats),Llamada a Teléfono celular,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row15_col0" class="data row15 col0" >1</td>
#       <td id="T_99a1a_row15_col1" class="data row15 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row16" class="row_heading level0 row16" >no</th>
#       <td id="T_99a1a_row16_col0" class="data row16 col0" >1</td>
#       <td id="T_99a1a_row16_col1" class="data row16 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row17" class="row_heading level0 row17" >Página web propia,Redes sociales (e.g. Facebook, Instagram)</th>
#       <td id="T_99a1a_row17_col0" class="data row17 col0" >1</td>
#       <td id="T_99a1a_row17_col1" class="data row17 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row18" class="row_heading level0 row18" >Llamada a Teléfono celular,Página web propia,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_99a1a_row18_col1" class="data row18 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row19" class="row_heading level0 row19" >Volantes</th>
#       <td id="T_99a1a_row19_col0" class="data row19 col0" >1</td>
#       <td id="T_99a1a_row19_col1" class="data row19 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row20" class="row_heading level0 row20" >Página web propia,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_99a1a_row20_col1" class="data row20 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row21" class="row_heading level0 row21" >Llamada a Teléfono celular,Llamada a Teléfono fijo,Redes sociales (e.g. Facebook, Instagram)</th>
#       <td id="T_99a1a_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_99a1a_row21_col1" class="data row21 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row22" class="row_heading level0 row22" >Llamada a Teléfono fijo,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_99a1a_row22_col1" class="data row22 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row23" class="row_heading level0 row23" >Aplicación móvil (e.g. Rappi, Uber Eats),Llamada a Teléfono celular,Llamada a Teléfono fijo,Redes sociales (e.g. Facebook, Instagram)</th>
#       <td id="T_99a1a_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_99a1a_row23_col1" class="data row23 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row24" class="row_heading level0 row24" >Aplicación móvil (e.g. Rappi, Uber Eats),Llamada a Teléfono fijo,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row24_col0" class="data row24 col0" >1</td>
#       <td id="T_99a1a_row24_col1" class="data row24 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row25" class="row_heading level0 row25" >Llamada a Teléfono celular,Llamada a Teléfono fijo,Página web propia,Redes sociales (e.g. Facebook, Instagram),WhatsApp</th>
#       <td id="T_99a1a_row25_col0" class="data row25 col0" >1</td>
#       <td id="T_99a1a_row25_col1" class="data row25 col1" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_99a1a_level0_row26" class="row_heading level0 row26" >Página web propia,WhatsApp</th>
#       <td id="T_99a1a_row26_c

# %%
frecuencias = df_retail['189_payment_methods'].value_counts()
tabla13 = pd.DataFrame({'Método de Pago': frecuencias.index, 'Frecuencia': frecuencias.values})
print(tabla13)
# Out:
#                                       Método de Pago  Frecuencia
# 0                                            Unknown          64
# 1                                           Efectivo          40
# 2  Efectivo,Tarjeta de débito y/o crédito,Transfe...          30
# 3             Efectivo,Tarjeta de débito y/o crédito          19
# 4               Efectivo,Transferencia interbancaria          15
# 5  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...           1
# 6  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...           1
# 7                      Tarjeta de débito y/o crédito           1

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_retail.index, df_retail['158_charact_organize_products_on_shelves'], alpha=0.5, color='red')
plt.xlabel('Índice de Registro')
plt.ylabel('Característica de Organización de Productos en Estantes')
plt.title('Organización de Productos en Estantes')
plt.grid(True)
plt.show()

# %%
tabla15 = df_retail['193_sales_planning_tools'].value_counts()
plt.figure(figsize=(10, 6))
plt.fill_between(frecuencias.index, frecuencias.values, color='yellow', alpha=0.7)
plt.xlabel('Herramientas de Planificación de Ventas')
plt.ylabel('Frecuencia')
plt.title('Gráfica de Área de Herramientas de Planificación de Ventas')
plt.xticks(rotation=90)
plt.show()

# %%
tabla16 = df_retail['60_services'].value_counts()
tabla16 = tabla16.head(5)
plt.figure(figsize=(8, 8))
plt.pie(tabla16, labels=tabla16.index, autopct='%1.1f%%', startangle=140)
plt.title('Gráfico de Pastel de Distribución de Servicios')
plt.show()

# %%
tabla17 = df_retail['69_why_not_services'].value_counts()
plt.figure(figsize=(10, 6))
tabla17.plot(kind='bar', rot=90, color='red')
plt.xlabel('Razones por las que no se utilizan los servicios')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Razones por las que no se Utilizan los Servicios')
plt.show()

# %%
frecuencias = df_retail['214_customer_relationship_tools'].value_counts()
tabla18 = frecuencias.head(5)
plt.figure(figsize=(8, 8))  # Ajusta el tamaño del gráfico si es necesario
plt.pie(tabla18, labels=tabla18.index, autopct='%1.1f%%', startangle=140)
plt.title('Principales 5 herramientas de relación cliente')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.fill_between(df_retail.index, df_retail['161_actions_stockouts'], color='red', alpha=0.7)
plt.xlabel('Índice de Registro')
plt.ylabel('Acciones para Evitar Rupturas de Stock')
plt.title('Acciones para Evitar Rupturas de Stock')
plt.grid(True)
plt.show()

# %%
tabla20 = df_retail['234_willingness_participate_workshop'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(tabla20, labels=tabla20.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightcoral', 'lightgreen'])
plt.title(' Disposición para Participar en Talleres')
plt.show()
